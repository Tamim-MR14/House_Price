# %% [markdown]
# #### ID : AI23
# #### Submission Date : 29th December, 2017

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.utils import check_random_state

# %%
def rmsle(y_pred, y_true): 
    
    return np.sqrt(np.square(np.log(y_pred + 1) - np.log(y_true + 1)).mean())

# %%
train_df=pd.read_csv('train.csv')
test_df=pd.read_csv('test.csv')
train_ID = train_df['Id']
test_ID = test_df['Id']
train_df.shape
seed = 0
np.random.seed(seed)
state=check_random_state(0)
state

# %%
ntrain = train_df.shape[0]
ntest = test_df.shape[0]
y_train = train_df.SalePrice.values
all_data = pd.concat((train_df, test_df)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
print(train_df.shape,test_df.shape)
# Out:
# all_data size is : (2919, 80)
# (1460, 81) (1459, 80)

# %%
all_data = all_data.fillna(0)
total = all_data.isnull().sum().sort_values(ascending=False)
percent = (all_data.isnull().sum()/all_data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                Total  Percent
# YrSold             0      0.0
# YearRemodAdd       0      0.0
# ExterCond          0      0.0
# ExterQual          0      0.0
# Exterior1st        0      0.0
# Exterior2nd        0      0.0
# Fence              0      0.0
# FireplaceQu        0      0.0
# Fireplaces         0      0.0
# Foundation         0      0.0
# FullBath           0      0.0
# Functional         0      0.0
# GarageArea         0      0.0
# GarageCars         0      0.0
# GarageCond         0      0.0
# GarageFinish       0      0.0
# GarageQual         0      0.0
# GarageType         0      0.0
# GarageYrBlt        0      0.0
# EnclosedPorch      0      0.0
# Electrical         0      0.0
# Condition2         0      0.0
# BsmtFinSF1         0      0.0
# 2ndFlrSF           0      0.0
# 3SsnPorch          0      0.0
# Alley              0      0.0
# BedroomAbvGr       0      0.0
# BldgType           0      0.0
# BsmtCond           0      0.0
# BsmtExposure       0      0.0
# ...              ...      ...
# SaleType           0      0.0
# Neighborhood       0      0.0
# ScreenPorch        0      0.0
# Street             0      0.0
# TotRmsAbvGrd       0      0.0
# TotalBsmtSF        0      0.0
# Utilities          0      0.0
# WoodDeckSF         0      0.0
# YearBuilt          0      0.0
# OpenPorchSF        0      0.0
# MoSold             0      0.0
# HeatingQC          0      0.0
# LotConfig          0      0.0
# HouseStyle         0      0.0
# Id                 0      0.0
# KitchenAbvGr       0      0.0
# KitchenQual        0      0.0
# LandContour        0      0.0
# LandSlope          0      0.0
# LotArea            0      0.0
# LotFrontage        0      0.0
# MiscVal            0      0.0
# LotShape           0      0.0
# LowQualFinSF       0      0.0
# MSSubClass         0      0.0
# MSZoning           0      0.0
# MasVnrArea         0      0.0
# MasVnrType         0      0.0
# MiscFeature        0      0.0
# 1stFlrSF           0      0.0
#
# [80 rows x 2 columns]

# %%
all_data['MSSubClass'] = all_data['MSSubClass'].astype('category')
all_data['OverallCond'] = all_data['OverallCond'].astype('category')
all_data['YrSold'] = all_data['YrSold'].astype('category')
all_data['MoSold'] = all_data['MoSold'].astype('category')

# %%
categoric_feats = list(test_df.dtypes[test_df.dtypes == "object"].index)
for items in categoric_feats:
    all_data[items]=all_data[items].astype('category').cat.codes
len(categoric_feats)
# Out:
# 43

# %%
all_data.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('int8'), dtype('float64'), category], dtype=object)

# %%
all_data.drop(['Id'], axis=1, inplace=True)
train_data = all_data[:ntrain]
test_data = all_data[ntrain:]
print(train_data.shape,test_data.shape)
# Out:
# (1460, 79) (1459, 79)

# %%
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(train_data)
X_test_scaled=scaler.fit_transform(test_data)
y_train=np.log(y_train)

# %%
layer=[]
a=0
for i in range(1,4):
    for j in [10,20,30,40,50]:
        a=j
        layer.append(tuple((np.ones(i)*j).astype(int)))
len(layer)
# Out:
# 15

# %%
ann=MLPRegressor(hidden_layer_sizes=(40,20,10),max_iter=1000,verbose=False)
param_grid={'activation':['relu','identity'],
            'solver':['lbfgs','adam'],
            'learning_rate':['constant','adaptive'],
            'alpha':[0.0001],
            'tol':[.0001]}
#grid = GridSearchCV(ann, param_grid, cv=5, scoring=make_scorer(mean_squared_error),n_jobs = -1)
grid = GridSearchCV(ann, param_grid, cv=10, scoring='r2')

grid.fit(X_train_scaled,y_train)
print(grid.best_score_)
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# 0.834869993602
# {'activation': 'identity', 'alpha': 0.0001, 'learning_rate': 'adaptive', 'solver': 'lbfgs', 'tol': 0.0001}
# MLPRegressor(activation='identity', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(40, 20, 10), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='lbfgs', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
test_y_grid = pd.DataFrame()
test_y_grid['Id'] = test_ID
test_y_grid['SalePrice'] = np.exp(grid.predict(X_test_scaled))
test_y_grid.to_csv('submission_grid.csv',index=0)

# %% [markdown]
# #### CNN

# %%
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D, Conv1D
from keras.layers.convolutional import MaxPooling2D,MaxPooling1D
from keras.utils import np_utils
from keras.layers import Embedding
from keras.utils.np_utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
def CNN(train_x_scaled_sample):
    model = Sequential()
    model.add(Conv1D(200, 1,strides=1, activation='relu', input_shape=(1,train_x_scaled_sample.shape[1])))
    model.add(Conv1D(200, 1,strides =1, activation='relu'))
    model.add(MaxPooling1D(1))
    model.add(Conv1D(100,1,strides=1, activation='relu'))
    model.add(Conv1D(100, 1,strides=1 ,activation='relu'))
    model.add(MaxPooling1D(1))
    model.add(Dropout(0.5))
    model.add(Dense(1,activation='relu'))
    return model

# %%
x=X_train_scaled
x_reshaped = np.reshape(x,(x.shape[0],1,x.shape[1]))
x_reshaped.shape
# Out:
# (1460, 1, 79)

# %%
y=y_train
y_reshape = np.reshape(y,(y.shape[0],1,-1))
y_reshape.shape
# Out:
# (1460, 1, 1)

# %%
model = CNN(x)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 1, 200)            16000
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1, 200)            40200
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 200)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1, 100)            20100
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 1, 100)            10100
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1, 100)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 100)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1)              101
# =================================================================
# Total params: 86,501
# Trainable params: 86,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
nb_epochs = 250
model.fit(x_reshaped,y_reshape,epochs=nb_epochs,validation_split=0.1,verbose=1,batch_size=1)
# Out:
# Train on 1314 samples, validate on 146 samples
# Epoch 1/250
# 1314/1314 [==============================] - 7s 6ms/step - loss: 13.0092 - val_loss: 1.7452
# Epoch 2/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 6.2613 - val_loss: 3.0032
# Epoch 3/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 4.9702 - val_loss: 1.1619
# Epoch 4/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 4.3930 - val_loss: 1.2355
# Epoch 5/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 3.8616 - val_loss: 0.7026
# Epoch 6/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 3.2520 - val_loss: 0.7794
# Epoch 7/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 3.0655 - val_loss: 2.9092
# Epoch 8/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 2.6885 - val_loss: 0.8959
# Epoch 9/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 2.3561 - val_loss: 0.3256
# Epoch 10/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 2.2720 - val_loss: 0.1451
# Epoch 11/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 2.2353 - val_loss: 0.3329
# Epoch 12/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 2.1836 - val_loss: 0.3014
# Epoch 13/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 2.0343 - val_loss: 0.3096
# Epoch 14/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 1.9216 - val_loss: 0.2256
# Epoch 15/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 1.7708 - val_loss: 0.6422
# Epoch 16/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.8738 - val_loss: 0.2497
# Epoch 17/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.6192 - val_loss: 0.0967
# Epoch 18/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.5864 - val_loss: 0.1034
# Epoch 19/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.6536 - val_loss: 0.0924
# Epoch 20/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.5281 - val_loss: 0.3472
# Epoch 21/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.3456 - val_loss: 0.4755
# Epoch 22/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 1.3242 - val_loss: 0.0866
# Epoch 23/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 1.1906 - val_loss: 0.0971
# Epoch 24/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.1870 - val_loss: 0.1451
# Epoch 25/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.2561 - val_loss: 0.0752
# Epoch 26/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 1.0824 - val_loss: 0.0803
# Epoch 27/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.9799 - val_loss: 0.0790
# Epoch 28/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.9806 - val_loss: 0.0772
# Epoch 29/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.9397 - val_loss: 0.0623
# Epoch 30/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.9340 - val_loss: 0.0637
# Epoch 31/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.8620 - val_loss: 0.3180
# Epoch 32/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.7807 - val_loss: 0.0673
# Epoch 33/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.7865 - val_loss: 0.0957
# Epoch 34/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.6940 - val_loss: 0.1516
# Epoch 35/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.6551 - val_loss: 0.1125
# Epoch 36/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.6573 - val_loss: 0.0504
# Epoch 37/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.5794 - val_loss: 0.0593
# Epoch 38/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.5676 - val_loss: 0.1143
# Epoch 39/250
# 1314/1314 [==============================] - 5s 3ms/step - loss: 0.5420 - val_loss: 0.2158
# Epoch 40/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.4979 - val_loss: 0.1611
# Epoch 41/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.4748 - val_loss: 0.0507
# Epoch 42/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.4179 - val_loss: 0.0549
# Epoch 43/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.4134 - val_loss: 0.0900
# Epoch 44/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.3810 - val_loss: 0.0976
# Epoch 45/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.3570 - val_loss: 0.0624
# Epoch 46/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.3358 - val_loss: 0.0641
# Epoch 47/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.3300 - val_loss: 0.0821
# Epoch 48/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2567 - val_loss: 0.0588
# Epoch 49/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2726 - val_loss: 0.0537
# Epoch 50/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2620 - val_loss: 0.0418
# Epoch 51/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.2083 - val_loss: 0.0497
# Epoch 52/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2065 - val_loss: 0.0511
# Epoch 53/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.1859 - val_loss: 0.0541
# Epoch 54/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.1749 - val_loss: 0.0514
# Epoch 55/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.1641 - val_loss: 0.0612
# Epoch 56/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.1496 - val_loss: 0.0479
# Epoch 57/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.1271 - val_loss: 0.0428
# Epoch 58/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.1124 - val_loss: 0.0427
# Epoch 59/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.1048 - val_loss: 0.0380
# Epoch 60/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0948 - val_loss: 0.0393
# Epoch 61/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0942 - val_loss: 0.0398
# Epoch 62/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0889 - val_loss: 0.0386
# Epoch 63/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0710 - val_loss: 0.0384
# Epoch 64/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0671 - val_loss: 0.0375
# Epoch 65/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0593 - val_loss: 0.0354
# Epoch 66/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0560 - val_loss: 0.0312
# Epoch 67/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0496 - val_loss: 0.0306
# Epoch 68/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0454 - val_loss: 0.0341
# Epoch 69/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0397 - val_loss: 0.0341
# Epoch 70/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0369 - val_loss: 0.0385
# Epoch 71/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0364 - val_loss: 0.0266
# Epoch 72/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0328 - val_loss: 0.0290
# Epoch 73/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0329 - val_loss: 0.0299
# Epoch 74/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0322 - val_loss: 0.0276
# Epoch 75/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0272 - val_loss: 0.0291
# Epoch 76/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0262 - val_loss: 0.0319
# Epoch 77/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0274 - val_loss: 0.0341
# Epoch 78/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0264 - val_loss: 0.0254
# Epoch 79/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0272 - val_loss: 0.0289
# Epoch 80/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0273 - val_loss: 0.0272
# Epoch 81/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0263 - val_loss: 0.0260
# Epoch 82/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0256 - val_loss: 0.0284
# Epoch 83/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0248 - val_loss: 0.0277
# Epoch 84/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0237 - val_loss: 0.0272
# Epoch 85/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0247 - val_loss: 0.0252
# Epoch 86/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0232 - val_loss: 0.0271
# Epoch 87/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0235 - val_loss: 0.0270
# Epoch 88/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0238 - val_loss: 0.0290
# Epoch 89/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0211 - val_loss: 0.0251
# Epoch 90/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0209 - val_loss: 0.0264
# Epoch 91/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0217 - val_loss: 0.0264
# Epoch 92/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0205 - val_loss: 0.0292
# Epoch 93/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0181 - val_loss: 0.0257
# Epoch 94/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0222 - val_loss: 0.0343
# Epoch 95/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0218 - val_loss: 0.0256
# Epoch 96/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0207 - val_loss: 0.0299
# Epoch 97/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0200 - val_loss: 0.0305
# Epoch 98/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0206 - val_loss: 0.0267
# Epoch 99/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0215 - val_loss: 0.0251
# Epoch 100/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0209 - val_loss: 0.0269
# Epoch 101/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0208 - val_loss: 0.0277
# Epoch 102/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0214 - val_loss: 0.0264
# Epoch 103/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0221 - val_loss: 0.0264
# Epoch 104/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0185 - val_loss: 0.0366
# Epoch 105/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0181 - val_loss: 0.0301
# Epoch 106/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0223 - val_loss: 0.0275
# Epoch 107/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0190 - val_loss: 0.0291
# Epoch 108/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0217 - val_loss: 0.0259
# Epoch 109/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0178 - val_loss: 0.0261
# Epoch 110/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0181 - val_loss: 0.0353
# Epoch 111/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0180 - val_loss: 0.0237
# Epoch 112/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0188 - val_loss: 0.0238
# Epoch 113/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0184 - val_loss: 0.0317
# Epoch 114/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0188 - val_loss: 0.0250
# Epoch 115/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0182 - val_loss: 0.0282
# Epoch 116/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0187 - val_loss: 0.0258
# Epoch 117/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0196 - val_loss: 0.0266
# Epoch 118/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0190 - val_loss: 0.0260
# Epoch 119/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0187 - val_loss: 0.0363
# Epoch 120/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0190 - val_loss: 0.0258
# Epoch 121/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0174 - val_loss: 0.0279
# Epoch 122/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0179 - val_loss: 0.0246
# Epoch 123/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0170 - val_loss: 0.0259
# Epoch 124/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0182 - val_loss: 0.0274
# Epoch 125/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0203 - val_loss: 0.0259
# Epoch 126/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0179 - val_loss: 0.0234
# Epoch 127/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0221 - val_loss: 0.0237
# Epoch 128/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0250 - val_loss: 0.0288
# Epoch 129/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0165 - val_loss: 0.0241
# Epoch 130/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0180 - val_loss: 0.0297
# Epoch 131/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0187 - val_loss: 0.0306
# Epoch 132/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0190 - val_loss: 0.0298
# Epoch 133/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0184 - val_loss: 0.0224
# Epoch 134/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0180 - val_loss: 0.0281
# Epoch 135/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0172 - val_loss: 0.0235
# Epoch 136/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0149 - val_loss: 0.0231
# Epoch 137/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0186 - val_loss: 0.0260
# Epoch 138/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0166 - val_loss: 0.0225
# Epoch 139/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0174 - val_loss: 0.0259
# Epoch 140/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0149 - val_loss: 0.0192
# Epoch 141/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0148 - val_loss: 0.0302
# Epoch 142/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0179 - val_loss: 0.0255
# Epoch 143/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0153 - val_loss: 0.0223
# Epoch 144/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0156 - val_loss: 0.0260
# Epoch 145/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0162 - val_loss: 0.0240
# Epoch 146/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0127 - val_loss: 0.0299
# Epoch 147/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0177 - val_loss: 0.0279
# Epoch 148/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0137 - val_loss: 0.0266
# Epoch 149/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0162 - val_loss: 0.0347
# Epoch 150/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0140 - val_loss: 0.0259
# Epoch 151/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0159 - val_loss: 0.0222
# Epoch 152/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0161 - val_loss: 0.0323
# Epoch 153/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0160 - val_loss: 0.0261
# Epoch 154/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0135 - val_loss: 0.0251
# Epoch 155/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0143 - val_loss: 0.0238
# Epoch 156/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0179 - val_loss: 0.0224
# Epoch 157/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0145 - val_loss: 0.0309
# Epoch 158/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0137 - val_loss: 0.0240
# Epoch 159/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0156 - val_loss: 0.0277
# Epoch 160/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0143 - val_loss: 0.0286
# Epoch 161/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0142 - val_loss: 0.0268
# Epoch 162/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0133 - val_loss: 0.0261
# Epoch 163/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0153 - val_loss: 0.0317
# Epoch 164/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0144 - val_loss: 0.0243
# Epoch 165/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0147 - val_loss: 0.0220
# Epoch 166/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0145 - val_loss: 0.0275
# Epoch 167/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0133 - val_loss: 0.0324
# Epoch 168/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0138 - val_loss: 0.0218
# Epoch 169/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0123 - val_loss: 0.0268
# Epoch 170/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0175 - val_loss: 0.0226
# Epoch 171/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0145 - val_loss: 0.0217
# Epoch 172/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0128 - val_loss: 0.0231
# Epoch 173/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0130 - val_loss: 0.0214
# Epoch 174/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0127 - val_loss: 0.0182
# Epoch 175/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0128 - val_loss: 0.0199
# Epoch 176/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0132 - val_loss: 0.0230
# Epoch 177/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0120 - val_loss: 0.0311
# Epoch 178/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0138 - val_loss: 0.0220
# Epoch 179/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0127 - val_loss: 0.0280
# Epoch 180/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0138 - val_loss: 0.0230
# Epoch 181/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0104 - val_loss: 0.0206
# Epoch 182/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0144 - val_loss: 0.0247
# Epoch 183/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0144 - val_loss: 0.0244
# Epoch 184/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0140 - val_loss: 0.0260
# Epoch 185/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0111 - val_loss: 0.0252
# Epoch 186/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0120 - val_loss: 0.0207
# Epoch 187/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0139 - val_loss: 0.0207
# Epoch 188/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0141 - val_loss: 0.0264
# Epoch 189/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0165 - val_loss: 0.0208
# Epoch 190/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0133 - val_loss: 0.0199
# Epoch 191/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0132 - val_loss: 0.0220
# Epoch 192/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0572 - val_loss: 0.0193
# Epoch 193/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0108 - val_loss: 0.0242
# Epoch 194/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0127 - val_loss: 0.0204
# Epoch 195/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0134 - val_loss: 0.0242
# Epoch 196/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0130 - val_loss: 0.0189
# Epoch 197/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0142 - val_loss: 0.0255
# Epoch 198/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0134 - val_loss: 0.0205
# Epoch 199/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0145 - val_loss: 0.0213
# Epoch 200/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0154 - val_loss: 0.0214
# Epoch 201/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0120 - val_loss: 0.0214
# Epoch 202/250
# 1314/1314 [==============================] - 5s 3ms/step - loss: 0.0123 - val_loss: 0.0223
# Epoch 203/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0142 - val_loss: 0.0263
# Epoch 204/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0137 - val_loss: 0.0254
# Epoch 205/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0144 - val_loss: 0.0258
# Epoch 206/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0123 - val_loss: 0.0195
# Epoch 207/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0137 - val_loss: 0.0230
# Epoch 208/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0148 - val_loss: 0.0209
# Epoch 209/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0149 - val_loss: 0.0225
# Epoch 210/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0127 - val_loss: 0.0261
# Epoch 211/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0133 - val_loss: 0.0233
# Epoch 212/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0108 - val_loss: 0.0264
# Epoch 213/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0121 - val_loss: 0.0212
# Epoch 214/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0144 - val_loss: 0.0231
# Epoch 215/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0112 - val_loss: 0.0303
# Epoch 216/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0130 - val_loss: 0.0251
# Epoch 217/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0131 - val_loss: 0.0219
# Epoch 218/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0116 - val_loss: 0.0261
# Epoch 219/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0133 - val_loss: 0.0234
# Epoch 220/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0131 - val_loss: 0.0189
# Epoch 221/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0131 - val_loss: 0.0206
# Epoch 222/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0130 - val_loss: 0.0210
# Epoch 223/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0122 - val_loss: 0.0258
# Epoch 224/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0136 - val_loss: 0.0254
# Epoch 225/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0149 - val_loss: 0.0228
# Epoch 226/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0114 - val_loss: 0.0242
# Epoch 227/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0154 - val_loss: 0.0275
# Epoch 228/250
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.0136 - val_loss: 0.0225
# Epoch 229/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0127 - val_loss: 0.0306
# Epoch 230/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0120 - val_loss: 0.0285
# Epoch 231/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0153 - val_loss: 0.0198
# Epoch 232/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0163 - val_loss: 0.0205
# Epoch 233/250
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.0122 - val_loss: 0.0192
# Epoch 234/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0174 - val_loss: 0.0238
# Epoch 235/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0148 - val_loss: 0.0244
# Epoch 236/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0125 - val_loss: 0.0196
# Epoch 237/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0139 - val_loss: 0.0230
# Epoch 238/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0139 - val_loss: 0.0248
# Epoch 239/250
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.0155 - val_loss: 0.0240
# Epoch 240/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0126 - val_loss: 0.0254
# Epoch 241/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0144 - val_loss: 0.0207
# Epoch 242/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0193 - val_loss: 0.0260
# Epoch 243/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0201 - val_loss: 0.0204
# Epoch 244/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0117 - val_loss: 0.0228
# Epoch 245/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0147 - val_loss: 0.0235
# Epoch 246/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0142 - val_loss: 0.0259
# Epoch 247/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0137 - val_loss: 0.0271
# Epoch 248/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0139 - val_loss: 0.0285
# Epoch 249/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0113 - val_loss: 0.0251
# Epoch 250/250
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.0123 - val_loss: 0.0305

# %%
test_x=X_test_scaled
test_x_reshape = np.reshape(test_x,(test_x.shape[0],1,test_x.shape[1]))
y_pred_cnn_reshape = model.predict(test_x_reshape)
y_pred_cnn_reshape.shape
# Out:
# (1459, 1, 1)

# %%
y_pred_cnn = np.reshape(y_pred_cnn_reshape,(-1,1))
y_pred_cnn.shape
# Out:
# (1459, 1)

# %%
y_pred_cnn = np.exp(y_pred_cnn)

# %%
y_pred_cnn
# Out:
# array([[ 124701.9375   ],
#        [ 171762.21875  ],
#        [ 196111.109375 ],
#        ...,
#        [ 182694.390625 ],
#        [ 127186.0859375],
#        [ 254847.       ]], dtype=float32)

# %%
test_y_cnn = pd.DataFrame()
test_y_cnn['Id'] = test_ID
test_y_cnn['SalePrice'] = y_pred_cnn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7f1f96246429> in <module>()
# ----> 1 test_y_cnn = pd.DataFrame()
#       2 test_y_cnn['Id'] = test_ID
#       3 test_y_cnn['SalePrice'] = y_pred_cnn
#
# NameError: name 'pd' is not defined

# %%
test_y_cnn.to_csv('submission_cnn.csv',index=0)
