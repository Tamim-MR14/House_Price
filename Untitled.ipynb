# %% [markdown]
# Reading The Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
from sklearn.pipeline import Pipeline
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import warnings
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neural_network import MLPRegressor
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score
from sklearn import metrics
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_df=pd.read_csv('train.csv')
test_df=pd.read_csv('test.csv')
train_df.head(5)
train_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#scatter plot grlivarea/saleprice
var = 'GrLivArea'
data = pd.concat([train_df['SalePrice'], train_df[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
#correlation matrix
corrmat = train_df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#saleprice correlation matrix
k = 30 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train_df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
#Handling Missing values
train_df = train_df.fillna(0)
'''categoric_feats = train_df.dtypes[train_df.dtypes == "object"].index
#train_df[categoric_feats[0]] = LabelEncoder().fit_transform(train_df[categoric_feats[0]])
for item in categoric_feats:
    train_df[item]=train_df[item].fillna(train_df[item].dropna().max())'''
total = train_df.isnull().sum().sort_values(ascending=False)
percent = (train_df.isnull().sum()/all_data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8cbf37c39557> in <module>()
#       6     train_df[item]=train_df[item].fillna(train_df[item].dropna().max())'''
#       7 total = train_df.isnull().sum().sort_values(ascending=False)
# ----> 8 percent = (train_df.isnull().sum()/all_data.isnull().count()).sort_values(ascending=False)
#       9 missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
#      10 missing_data
#
# NameError: name 'all_data' is not defined

# %%
#Handling Missing values
test_df = test_df.fillna(0)
'''categoric_feats = test_df.dtypes[test_df.dtypes == "object"].index
#train_df[categoric_feats[0]] = LabelEncoder().fit_transform(train_df[categoric_feats[0]])
for item in categoric_feats:
    test_df[item]=test_df[item].fillna(test_df[item].dropna().max())'''

total = test_df.isnull().sum().sort_values(ascending=False)
percent = (test_df.isnull().sum()/test_df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#               Total  Percent
# BsmtHalfBath      0      0.0
# BsmtFinSF1        0      0.0
# GrLivArea         0      0.0
# GarageCars        0      0.0
# GarageArea        0      0.0
# TotalBsmtSF       0      0.0
# 1stFlrSF          0      0.0
# FullBath          0      0.0
# TotRmsAbvGrd      0      0.0
# YearBuilt         0      0.0
# YearRemodAdd      0      0.0
# GarageYrBlt       0      0.0
# MasVnrArea        0      0.0
# Fireplaces        0      0.0
# LotFrontage       0      0.0
# BsmtFinSF2        0      0.0
# WoodDeckSF        0      0.0
# 2ndFlrSF          0      0.0
# OpenPorchSF       0      0.0
# HalfBath          0      0.0
# LotArea           0      0.0
# BsmtFullBath      0      0.0
# BsmtUnfSF         0      0.0
# BedroomAbvGr      0      0.0
# ScreenPorch       0      0.0
# PoolArea          0      0.0
# MoSold            0      0.0
# 3SsnPorch         0      0.0
# OverallQual       0      0.0

# %%
train_df=train_df[list(cols)]
train_data=train_df.drop('SalePrice',axis=1).values
train_target=train_df['SalePrice'].values

test_df=test_df[cols.drop('SalePrice')]
test_data=test_df.values

scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(train_data)
X_test_scaled=scaler.fit_transform(test_data)

# %%
clf = MLPRegressor(max_iter = 200, solver='lbfgs', hidden_layer_sizes = (50,50), activation='relu')
clf.fit(X_train_scaled, train_target)
scores = cross_val_score( clf, X_train_scaled, train_target, cv=10, scoring='mean_squared_error')
scores
# Out:
# array([ -8.31407959e+08,  -1.06297485e+09,  -1.48216983e+09,
#         -4.90606167e+09,  -1.45773633e+09,  -9.67765413e+08,
#         -8.87561313e+08,  -1.02368781e+09,  -4.03134631e+09,
#         -1.25254394e+09])
